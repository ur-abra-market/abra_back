# %%
import pandas as pd

df = pd.read_csv('company.csv',  delimiter=',')
import random

# df['property_type_id'] = df['property_type_id'].apply(lambda x : random.randint(1,4) if x == 5 else  x )
df
# df.to_csv('category_properties.csv')
# df['property_type_id'].unique()
# Out:
#     id  supplier_id                                name  is_manufacturer  \
# 0    1            1                 Mathis and Sons Ltd             True
# 1    2            2                   Costa-Blevins LLC             True
# 2    3            1                   Nelson-Taylor Ltd            False
# 3    4            2                Smith-Perez and Sons            False
# 4    5            3                      Obrien Ltd LLC            False
# 5    6            4                   Morris-Palmer PLC             True
# 6    7            5                    Santos Group Inc             True
# 7    8            6                   Love-Martinez PLC            False
# 8    9            7                      Miller Inc PLC            False
# 9   10            8                     Branch-Pugh Inc            False
# 10  11            9                   Miller-Harper Inc             True
# 11  12           10                     Wyatt-Ortiz Inc             True
# ...

# %%
# sellers = range(1, 59)
from datetime import datetime
import random

now = datetime.now()
statuses = list(range(1,6))
statuses.extend([7,8])
is_cart = False
res = []
for i in range(2,100):
    res.append({
        'id':i,
        'datetime':now,
        'updated_at':now,
        'is_cart':random.choice([True, False]),
        'seller_id':random.randint(1,60),
        'status_id':random.choice(statuses)
    })

pd.DataFrame(res).to_csv('order.csv')

# %%
res = []
for i in range(100):
    res.append({
        'id':i+1,
        'count':random.randint(0,100),
        'order_id':random.randint(1,100),
        'status_id':random.choice(statuses),
        'product_variation_count_id':random.randint(839, 1003)
    })

pd.DataFrame(res).to_csv('order_product_variarion.csv')
